# %%
import pandas as pd
import re
import numpy as np

# %%
df = pd.read_csv('./prevalence-by-mental-and-substance-use-disorder.csv')

# %%
df
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 6835     Zimbabwe  ZWE  2015
# 6836     Zimbabwe  ZWE  2016
# 6837     Zimbabwe  ZWE  2017
# 6838     Zimbabwe  ZWE  2018
# 6839     Zimbabwe  ZWE  2019
#
#       Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                                  0.23
# 1                                                  0.23
# 2                                                  0.23
# 3                                                  0.23
# 4                                                  0.23
# ...                                                 ...
# 6835                                               0.21
# 6836                                               0.21
# 6837                                               0.21
# ...

# %%
df2 = df.groupby(['Year']).median().reset_index()

# %%
df2
# Out:
#     Year  \
# 0   1990
# 1   1991
# 2   1992
# 3   1993
# 4   1994
# 5   1995
# 6   1996
# 7   1997
# 8   1998
# 9   1999
# 10  2000
# 11  2001
# 12  2002
# 13  2003
# 14  2004
# 15  2005
# 16  2006
# 17  2007
# 18  2008
# 19  2009
# 20  2010
# 21  2011
# 22  2012
# 23  2013
# 24  2014
# 25  2015
# 26  2016
# 27  2017
# 28  2018
# 29  2019
#
#     Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                                0.28
# 1                                                0.28
# 2                                                0.29
# 3                                                0.29
# 4                                                0.29
# 5                                                0.29
# 6                                                0.29
# 7                                                0.29
# 8                                                0.29
# 9                                                0.29
# ...

# %%
df_melt = df2.melt(id_vars=['Year'])
df_melt
# Out:
#      Year                                           variable  value
# 0    1990  Prevalence - Schizophrenia - Sex: Both - Age: ...  0.280
# 1    1991  Prevalence - Schizophrenia - Sex: Both - Age: ...  0.280
# 2    1992  Prevalence - Schizophrenia - Sex: Both - Age: ...  0.290
# 3    1993  Prevalence - Schizophrenia - Sex: Both - Age: ...  0.290
# 4    1994  Prevalence - Schizophrenia - Sex: Both - Age: ...  0.290
# ..    ...                                                ...    ...
# 205  2015  Prevalence - Alcohol use disorders - Sex: Both...  1.420
# 206  2016  Prevalence - Alcohol use disorders - Sex: Both...  1.405
# 207  2017  Prevalence - Alcohol use disorders - Sex: Both...  1.410
# 208  2018  Prevalence - Alcohol use disorders - Sex: Both...  1.420
# 209  2019  Prevalence - Alcohol use disorders - Sex: Both...  1.435
#
# [210 rows x 3 columns]

# %%
df_melt.to_csv('.//prevalence-by-mental-and-substance-use-disorder_MEDIANPERYEAR.csv')

# %%
dfx = pd.read_csv('./number-with-mental-and-neurodevelopmental-disorders-by-type.csv')

# %%
dfx
# Out:
#            Entity Code  Year  \
# 0     Afghanistan  AFG  1990
# 1     Afghanistan  AFG  1991
# 2     Afghanistan  AFG  1992
# 3     Afghanistan  AFG  1993
# 4     Afghanistan  AFG  1994
# ...           ...  ...   ...
# 7703     Zimbabwe  ZWE  2015
# 7704     Zimbabwe  ZWE  2016
# 7705     Zimbabwe  ZWE  2017
# 7706     Zimbabwe  ZWE  2018
# 7707     Zimbabwe  ZWE  2019
#
#       Prevalence - Depressive disorders - Sex: Both - Age: All Ages (Number)  \
# 0                                              439837.0
# 1                                              478890.0
# 2                                              545449.0
# 3                                              593044.0
# 4                                              613915.0
# ...                                                 ...
# 7703                                           354911.0
# 7704                                           363160.0
# 7705                                           371659.0
# ...

# %%
dfxm = dfx.groupby(['Year']).median().reset_index()

# %%
dfxm
# Out:
#     Year  \
# 0   1990
# 1   1991
# 2   1992
# 3   1993
# 4   1994
# 5   1995
# 6   1996
# 7   1997
# 8   1998
# 9   1999
# 10  2000
# 11  2001
# 12  2002
# 13  2003
# 14  2004
# 15  2005
# 16  2006
# 17  2007
# 18  2008
# 19  2009
# 20  2010
# 21  2011
# 22  2012
# 23  2013
# 24  2014
# 25  2015
# 26  2016
# 27  2017
# 28  2018
# 29  2019
#
#     Prevalence - Depressive disorders - Sex: Both - Age: All Ages (Number)  \
# 0                                            203722.5
# 1                                            207751.0
# 2                                            209561.0
# 3                                            216206.0
# 4                                            216001.0
# 5                                            226794.5
# 6                                            230481.5
# 7                                            234558.5
# 8                                            237681.5
# 9                                            240896.5
# ...

# %%
dfxm2 = dfxm.melt(id_vars=['Year'])
dfxm2
# Out:
#      Year                                           variable     value
# 0    1990  Prevalence - Depressive disorders - Sex: Both ...  203722.5
# 1    1991  Prevalence - Depressive disorders - Sex: Both ...  207751.0
# 2    1992  Prevalence - Depressive disorders - Sex: Both ...  209561.0
# 3    1993  Prevalence - Depressive disorders - Sex: Both ...  216206.0
# 4    1994  Prevalence - Depressive disorders - Sex: Both ...  216001.0
# ..    ...                                                ...       ...
# 295  2015  Prevalence - Autism spectrum disorders - Sex: ...   34907.5
# 296  2016  Prevalence - Autism spectrum disorders - Sex: ...   35242.5
# 297  2017  Prevalence - Autism spectrum disorders - Sex: ...   35498.0
# 298  2018  Prevalence - Autism spectrum disorders - Sex: ...   35886.5
# 299  2019  Prevalence - Autism spectrum disorders - Sex: ...   36565.0
#
# [300 rows x 3 columns]

# %%
dfxm2.to_csv('./mediana_esmental_90a19.csv')
